# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('Housing.csv')
df.head()
# Out:
#       price  area
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([461.97489427])

# %%
model.intercept_
# Out:
# np.float64(2387308.4823964303)

# %%
model.predict([[7500]])
# Out:
# C:\Users\star\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5852120.18944231])

# %%
import pickle

# %%
with open('model_pickle','wb') as f:   #write mode
    pickle.dump(model,f)

# %%
with open('model_pickle','rb') as f:    #read mode
    model1 = pickle.load(f)

# %%
model1.predict([[7500]])
# Out:
# C:\Users\star\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5852120.18944231])

# %%
import joblib

# %%
 joblib.dump(model,'joblib_model')
# Out:
# ['joblib_model']

# %%
obj = joblib.load('joblib_model')

# %%
obj.predict([[7500]])
# Out:
# C:\Users\star\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5852120.18944231])
